# %% [markdown]
# ## FRIENDS Data Analysis

# %% [markdown]
# ____
# ** Import numpy and pandas **

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ** Import visualization libraries and set %matplotlib inline. **

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# ** Read in the csv file as a dataframe called df **

# %%
df = pd.read_csv('../dataset/friends_dataset_allseasons.csv',sep='\t')
df['Location'] = df['Location'].replace('the hallway', 'The Hallway')

# %% [markdown]
# ** Check the info() of the df **

# %%
df.info()

# %% [markdown]
# ** Check the head of df **

# %%
df.head(5)

# %% [markdown]
# ## Basic Questions

# %% [markdown]
# ** What are the top 6 Lead Charactes? **

# %%
df['Character'].value_counts().head(6)

# %% [markdown]
# ** What are the top 5 supporting characters? **

# %%
#Ignoring Character == 'All'
df_new = df[df['Character'] != 'All']
df_new['Character'].value_counts().head(12).tail(6)

# %% [markdown]
# ** What are the top 5 set(Location)? **

# %%
df['Location'].value_counts().head(6)

# %% [markdown]
# # Total number of lines by each lead characters

# %%
df_leadcharacters=df[(df['Character'] == 'Chandler') | (df['Character'] == 'Ross') | (df['Character'] == 'Joey')  |(df['Character'] == 'Monica') | (df['Character'] == 'Rachel') | (df['Character'] == 'Phoebe')      ]
sns.countplot(x='Character',data=df_leadcharacters)

# %% [markdown]
# Findings: Ross and Rachel had more lines(Dialogues) than anyone else.
#           Rachel and Ross both had 9k+ lines. This was really close. While Phoebe had the least number of lines, 7.5k.

# %% [markdown]
# # Total number of lines by supporting characters

# %% [markdown]
# ** Now use seaborn to create a countplot Friends by Supporting Characters. **
# Mike          360
# Richard       254
# Mr. Geller    231
# Janice        219
# Carol         205
# Charlie       190

# %%
df_supporingcharacters=df[(df['Character'] == 'Mike') | (df['Character'] == 'Richard') | (df['Character'] == 'Mr. Geller')  |(df['Character'] == 'Janice') | (df['Character'] == 'Carol') | (df['Character'] == 'Charlie')      ]
sns.countplot(x='Character',data=df_supporingcharacters)

# %%
Findings: Despite 'Gunther' appeared in most number of sean. Interestingly Mike and Richard had the most number of Lines (Dialogue).

# %% [markdown]
# # The Main Set (Location)

# %% [markdown]
# ** Now use seaborn to create a countplot Friends by Location. **
# Monica's Apartment               18561
# Central Perk                     10896
# Chandler and Joey's Apartment     7188
# Ross's Apartment                  1228
# The Hallway                        692
# Ross and Rachel's Apartment        599

# %%
df_locations=df[(df['Location'] == "Monica's Apartment") | (df['Location'] == "Central Perk") | (df['Location'] == "Chandler and Joey's Apartment")  |(df['Location'] == "Ross's Apartment") | (df['Location'] == 'The Hallway') | (df['Location'] == "Ross and Rachel's Apartment")  ]
sns.countplot(x='Location',data=df_locations)

# %% [markdown]
# Findings: The main set for Friends was Monica's Apartment then 'Central Perk'

# %% [markdown]
# # Total Number of Lines by each lead characters at Central Perk

# %%
df_linesat_centralperkt=df[((df['Character'] == 'Chandler') | (df['Character'] == 'Ross') | (df['Character'] == 'Joey')  |(df['Character'] == 'Monica') | (df['Character'] == 'Rachel') | (df['Character'] == 'Phoebe')) & (df['Location'] == "Central Perk")]
sns.countplot(x='Character',data=df_linesat_centralperkt)

# %%
Findings: Phoebe had the most number of lines in 'Central Perk' followed by Ross and then Rachel.

# %% [markdown]
# # Total Number of Lines by each lead characters at Monica's Apartment

# %%
df_linesat_monicaspartment=df[((df['Character'] == 'Chandler') | (df['Character'] == 'Ross') | (df['Character'] == 'Joey')  |(df['Character'] == 'Monica') | (df['Character'] == 'Rachel') | (df['Character'] == 'Phoebe')) & (df['Location'] == "Monica's Apartment")]
sns.countplot(x='Character',data=df_linesat_monicaspartment)

# %%
Findings: Of course, no surprises here. Monica had the most number of lines in her apartment followed by Chandler and then Rachel.

# %% [markdown]
# # Total number of lines by each lead characters in each season

# %% [markdown]
# ** Now use seaborn to create a countplot of the Season column with the hue based off of the Character column. **

# %%
sns.countplot(x='Season',data=df_leadcharacters,hue='Character',palette='viridis')

# To relocate the legend
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# # Total number of lines by each lead characters in each set

# %%
sns.countplot(x='Season',data=df_locations,hue='Location',palette='viridis')

# To relocate the legend
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# ** Now create a gropuby object called bySeason, where you group the DataFrame by the Seasib column and use the count() method for aggregation. Use the head() method on this returned DataFrame. **

# %%
bySeason = df.groupby('Season').count()
bySeason.head(10)

# %% [markdown]
# # creating a simple plot off of the dataframe indicating the no. of lines(Dialogue) per season.

# %%
# Could be any column
bySeason['Dialogue'].plot()

# %% [markdown]
# # Now see if we can use seaborn's lmplot() to create a linear fit on the number of lines per season.

# %%
#need to reset the index to a column. 
sns.lmplot(x='Season',y='Dialogue',data=bySeason.reset_index())

# %% [markdown]
# # heatmap

# %%
df['Episode'].unique()

# %%
df['Episode'] = df['Episode'].replace('23-24', '23')
df['Episode'] = df['Episode'].replace('17-18', '17')

# %%
SeasonEpisode = df.groupby(by=['Season','Episode']).count()['Dialogue'].unstack().fillna(0)
SeasonEpisode.head(10)

# %% [markdown]
# ** Now create a HeatMap using this new DataFrame. **

# %%
plt.figure(figsize=(12,6))
sns.heatmap(SeasonEpisode,cmap='viridis')

# %% [markdown]
# ** Now create a clustermap using this DataFrame. **

# %%
sns.clustermap(SeasonEpisode,cmap='viridis')

# %%
df_leadcharacters.groupby('Character').describe()

# %%
df_leadcharacters['Lengthofdialogue'] = df_leadcharacters['Dialogue'].apply(len)
df_leadcharacters.head(2)

# %%
df_leadcharacters['Lengthofdialogue'].plot.hist(bins=100)

# %%
df_leadcharacters.hist(column='Lengthofdialogue',by="Character",bins=200,figsize=(12,4))

# %%
Findings: As expected Rachel has long dialogue
# Out:
#   File "<ipython-input-311-3fe31f5c9115>", line 1
#     Findings: As expected Rachel has long dialogue
#                         ^
# SyntaxError: invalid syntax

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopwords.words('english')[0:10] # Show some stop words
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
import string

# %%
def text_process(mess):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Returns a list of the cleaned text
    """
    
    mess = mess.lower()
    
    
    # Check characters to see if they are in punctuation
    nopunc = [char for char in mess if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Now just remove any stopwords
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
# Apply a first round of text cleaning techniques
import re
import string
from nltk.stem import PorterStemmer

#create an object of class PorterStemmer
porter = PorterStemmer()

def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[[^\]*]\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    #text = re.sub('[!"#$%&\'()*+,-./:;<=>?@[\]\\\^_{|}~`]','',text) 
    text = re.sub('\w*\d\w*', '', text)
    text = porter.stem(text)
    # Now just remove any stopwords
    return ' '.join([word for word in text.split() if word.lower() not in stopwords.words('english')])
    #return text

round1 = lambda x: clean_text_round1(x)

# %%
print (round1("test testing tested will test !@#$% 4353"))
# Out:
# test testing tested test

# %%
df_leadcharacters[['Character','Dialogue']].head(5)
# Out:
#   Character                                           Dialogue
# 0    Monica  There's nothing to tell! He's just some guy I ...
# 1      Joey  C'mon, you're going out with the guy! There's ...
# 2  Chandler  All right Joey, be nice.  So does he have a hu...
# 3    Phoebe                            Wait, does he eat chalk
# 4    Phoebe  Just, 'cause, I don't want her to go through w...

# %%
df_lcd = df_leadcharacters[['Character','Dialogue']]

# %%
df_lcd.head(10)
# Out:
#    Character                                           Dialogue
# 0     Monica  There's nothing to tell! He's just some guy I ...
# 1       Joey  C'mon, you're going out with the guy! There's ...
# 2   Chandler  All right Joey, be nice.  So does he have a hu...
# 3     Phoebe                            Wait, does he eat chalk
# 4     Phoebe  Just, 'cause, I don't want her to go through w...
# 5     Monica  Okay, everybody relax. This is not even a date...
# 6   Chandler                          Sounds like a date to me.
# 7   Chandler  Alright, so I'm back in high school, I'm stand...
# 9   Chandler  Then I look down, and I realize there's a phon...
# 10      Joey                                      Instead of...

# %%
# Check to make sure its working
df_lcd['Dialogue'].head(5).apply(text_process)
# Out:
# 0              [theres, nothing, tell, hes, guy, work]
# 1    [cmon, youre, going, guy, theres, gotta, somet...
# 2           [right, joey, nice, hump, hump, hairpiece]
# 3                                   [wait, eat, chalk]
# 4              [cause, dont, want, go, went, carl, oh]
# Name: Dialogue, dtype: object

# %%
df_lcd_new=df_lcd.groupby('Character')['Dialogue'].apply(','.join).reset_index()
df_lcd_new.head(6)
# Out:
#   Character                                           Dialogue
# 0  Chandler  All right Joey, be nice.  So does he have a hu...
# 1      Joey  C'mon, you're going out with the guy! There's ...
# 2    Monica  There's nothing to tell! He's just some guy I ...
# 3    Phoebe  Wait, does he eat chalk,Just, 'cause, I don't ...
# 4    Rachel  Oh God Monica hi! Thank God! I just went to yo...
# 5      Ross  (mortified) Hi.,I just feel like someone reach...

# %%
df_lcd[df_lcd['Character'] == 'Monica']
# Out:
#       Character                                           Dialogue
# 0        Monica  There's nothing to tell! He's just some guy I ...
# 5        Monica  Okay, everybody relax. This is not even a date...
# 15       Monica           And they weren't looking at you before?!
# 19       Monica                              Are you okay, sweetie
# 22       Monica  (explaining to the others) Carol moved her stu...
# ...         ...                                                ...
# 61503    Monica                             Oh, yeah, that's true.
# 61505    Monica  Wait a minute. What about that summer during c...
# 61507    Monica  Oh, honey, I forgot. I promised Treeger that w...
# 61511    Monica  (crying) This is harder than I thought it woul...
# 61514    Monica                                  We got some time.
#
# [8437 rows x 2 columns]

# %%
# Check to make sure its working
#df_lcd_new['Dialogue'] = df_lcd_new['Dialogue'].apply(text_process)
df_lcd_new['Dialogue'] = df_lcd_new['Dialogue'].apply(round1)

# %%
# Let's take a look at the updated text
#data_clean = df_lcd_new['Dialogue'].apply(round1)
#data_clean = pd.DataFrame(df_lcd_new.Dialogue.apply(round1))
df_lcd_new
# Out:
#   Character                                           Dialogue
# 0  Chandler  right joey nice hump hump hairpiecesounds like...
# 1      Joey  cmon youre going guy theres gotta something wr...
# 2    Monica  theres nothing tell hes guy work withokay ever...
# 3    Phoebe  wait eat chalkjust cause dont want go went car...
# 4    Rachel  oh god monica hi thank god went building weren...
# 5      Ross  mortified hii feel like someone reached throat...

# %%
#set column as index
data_clean = df_lcd_new.set_index('Character')
data_clean
# Out:
#                                                     Dialogue
# Character
# Chandler   right joey nice hump hump hairpiecesounds like...
# Joey       cmon youre going guy theres gotta something wr...
# Monica     theres nothing tell hes guy work withokay ever...
# Phoebe     wait eat chalkjust cause dont want go went car...
# Rachel     oh god monica hi thank god went building weren...
# Ross       mortified hii feel like someone reached throat...

# %%
# We are going to create a document-term matrix using CountVectorizer, and exclude common English stop words
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words='english')
#cv = CountVectorizer(stop_words='english',ngram_range=(1,2))
data_cv = cv.fit_transform(data_clean['Dialogue'])
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_dtm.index = data_clean.index
data_dtm
# Out:
#            aa  aaaaaaaaaaaaaaaaaaaaaaaaaaadoptionoh  aaaaaahhhh  aaaaaahhhhhh  \
# Character
# Chandler    0                                     1           0             0
# Joey        0                                     0           0             1
# Monica      4                                     0           0             0
# Phoebe      0                                     0           1             0
# Rachel      0                                     0           0             0
# Ross        3                                     0           0             0
#
#            aaaaaahhhhi  aaaaahh  aaaaahhhhh  aaah  aaahah  aaahh  ...  zoos  \
# Character                                                         ...
# Chandler             1        0           0     0       0      0  ...     0
# Joey                 0        0           1     0       0      0  ...     0
# Monica               0        0           0     0       0      0  ...     0
# Phoebe               0        0           0     0       0      0  ...     0
# Rachel               0        1           0     0       0      1  ...     0
# Ross                 0        0           0     1       1      0  ...     2
#
#            zoosingin  zoowell  zoowhatah  zooyesnono  zorps  zurich  zxy  \
# Character
# Chandler           0        0          1           0      1       0    0
# Joey               0        0          0           0      0       0    0
# Monica             0        0          0           0      0       0    1
# Phoebe             0        0          0           0      0       1    0
# Rachel             0        0          0           0      0       0    0
# Ross               1        1          0           1      0       0    0
#
#            zxywell  zygomatic
# Character
# Chandler         0          0
# Joey             0          1
# Monica           1          0
# Phoebe           0          0
# Rachel           0          0
# Ross             0          0
#
# [6 rows x 44608 columns]

# %%
# pickle imports
import pickle

# Let's pickle it for later use
data_dtm.to_pickle("../pickle/dtm.pkl")

# %%
# Let's also pickle the cleaned data (before we put it in document-term matrix format) and the CountVectorizer object
data_clean.to_pickle('../pickle/data_clean.pkl')
pickle.dump(cv, open("../pickle/cv.pkl", "wb"))

# %%
## Analysis

# %%
# Read in the document-term matrix

data = pd.read_pickle('../pickle/dtm.pkl')
data = data.transpose()
data.head()
# Out:
# Character                             Chandler  Joey  Monica  Phoebe  Rachel  \
# aa                                           0     0       4       0       0
# aaaaaaaaaaaaaaaaaaaaaaaaaaadoptionoh         1     0       0       0       0
# aaaaaahhhh                                   0     0       0       1       0
# aaaaaahhhhhh                                 0     1       0       0       0
# aaaaaahhhhi                                  1     0       0       0       0
#
# Character                             Ross
# aa                                       3
# aaaaaaaaaaaaaaaaaaaaaaaaaaadoptionoh     0
# aaaaaahhhh                               0
# aaaaaahhhhhh                             0
# aaaaaahhhhi                              0

# %%
# Find the top 30 words said for each resort
top_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(50)
    top_dict[c]= list(zip(top.index, top.values))
top_dict
# Out:
# {'Chandler': [('know', 735),
#   ('like', 409),
#   ('gonna', 403),
#   ('right', 385),
#   ('im', 376),
#   ('think', 352),
#   ('joey', 346),
#   ('monica', 324),
#   ('okay', 312),
#   ('don', 291),
#   ('look', 288),
#   ('dont', 283),
#   ('ross', 253),
#   ('got', 243),
#   ('uh', 240),
#   ('mean', 223),
#   ('really', 220),
#   ('want', 206),
#   ('say', 198),
#   ('going', 193),
#   ('thats', 183),
#   ('oh', 178),
#   ('good', 176),
#   ('yeah', 169),
#   ('little', 163),
#   ('tell', 157),
#   ('come', 152),
#   ('time', 147),
#   ('guys', 143),
#   ('youre', 140),
#   ('thing', 136),
#   ('great', 134),
#   ('love', 133),
#   ('said', 131),
#   ('yknow', 129),
#   ('let', 126),
#   ('make', 124),
#   ('chandler', 124),
#   ('way', 120),
#   ('guy', 117),
#   ('big', 116),
#   ('hey', 113),
#   ('rachel', 109),
#   ('ve', 109),
#   ('sorry', 107),
#   ('ll', 106),
#   ('wanna', 106),
#   ('yes', 105),
#   ('phoebe', 99),
#   ('didnt', 98)],
#  'Joey': [('know', 792),
#   ('right', 539),
#   ('like', 539),
#   ('hey', 408),
#   ('ross', 389),
#   ('gonna', 377),
#   ('uh', 377),
#   ('got', 353),
#   ('chandler', 347),
#   ('look', 344),
#   ('im', 339),
#   ('don', 326),
#   ('okay', 321),
#   ('yeah', 308),
#   ('think', 288),
#   ('dont', 270),
#   ('really', 267),
#   ('want', 258),
#   ('oh', 258),
#   ('good', 232),
#   ('guys', 220),
#   ('come', 216),
#   ('little', 194),
#   ('joey', 194),
#   ('mean', 190),
#   ('ll', 186),
#   ('rachel', 183),
#   ('say', 177),
#   ('monica', 175),
#   ('youre', 166),
#   ('tell', 164),
#   ('man', 158),
#   ('guy', 158),
#   ('going', 156),
#   ('great', 155),
#   ('said', 142),
#   ('looks', 141),
#   ('thing', 135),
#   ('thats', 130),
#   ('starts', 129),
#   ('let', 128),
#   ('phoebe', 128),
#   ('make', 118),
#   ('maybe', 118),
#   ('sorry', 117),
#   ('big', 116),
#   ('gotta', 116),
#   ('listen', 116),
#   ('time', 113),
#   ('ya', 112)],
#  'Monica': [('know', 631),
#   ('gonna', 445),
#   ('chandler', 385),
#   ('right', 380),
#   ('like', 335),
#   ('think', 325),
#   ('really', 317),
#   ('mean', 307),
#   ('im', 306),
#   ('okay', 304),
#   ('dont', 288),
#   ('oh', 288),
#   ('don', 270),
#   ('rachel', 257),
#   ('god', 249),
#   ('want', 245),
#   ('got', 243),
#   ('phoebe', 242),
#   ('going', 217),
#   ('ross', 200),
#   ('look', 200),
#   ('joey', 199),
#   ('youre', 196),
#   ('come', 194),
#   ('little', 189),
#   ('tell', 170),
#   ('love', 160),
#   ('good', 153),
#   ('umm', 152),
#   ('guys', 139),
#   ('sorry', 136),
#   ('ll', 134),
#   ('make', 132),
#   ('time', 130),
#   ('wanna', 129),
#   ('say', 126),
#   ('let', 125),
#   ('wait', 120),
#   ('monica', 118),
#   ('great', 118),
#   ('guy', 116),
#   ('maybe', 115),
#   ('thats', 115),
#   ('hey', 112),
#   ('yeah', 112),
#   ('uh', 111),
#   ('believe', 109),
#   ('thought', 100),
#   ('way', 99),
#   ('need', 96)],
#  'Phoebe': [('know', 929),
#   ('oh', 542),
#   ('like', 531),
#   ('okay', 456),
#   ('im', 362),
#   ('right', 362),
#   ('gonna', 358),
#   ('really', 330),
#   ('dont', 275),
#   ('don', 263),
#   ('yeah', 262),
#   ('monica', 245),
#   ('think', 244),
#   ('look', 239),
#   ('rachel', 220),
#   ('god', 218),
#   ('ross', 212),
#   ('want', 204),
#   ('good', 201),
#   ('guys', 192),
#   ('joey', 191),
#   ('chandler', 188),
#   ('got', 174),
#   ('mean', 174),
#   ('sorry', 165),
#   ('yknow', 162),
#   ('youre', 160),
#   ('ok', 156),
#   ('going', 154),
#   ('tell', 152),
#   ('thats', 150),
#   ('hey', 149),
#   ('guy', 143),
#   ('little', 142),
#   ('cause', 136),
#   ('umm', 134),
#   ('um', 132),
#   ('come', 130),
#   ('time', 130),
#   ('phoebe', 129),
#   ('say', 129),
#   ('great', 124),
#   ('love', 118),
#   ('make', 117),
#   ('hes', 116),
#   ('wait', 115),
#   ('let', 113),
#   ('maybe', 111),
#   ('said', 107),
#   ('looks', 106)],
#  'Rachel': [('know', 1076),
#   ('oh', 670),
#   ('gonna', 555),
#   ('ross', 535),
#   ('right', 456),
#   ('like', 437),
#   ('mean', 426),
#   ('im', 410),
#   ('don', 390),
#   ('god', 388),
#   ('okay', 381),
#   ('really', 375),
#   ('think', 367),
#   ('joey', 327),
#   ('dont', 301),
#   ('look', 282),
#   ('got', 274),
#   ('want', 259),
#   ('guys', 259),
#   ('come', 253),
#   ('monica', 250),
#   ('yeah', 246),
#   ('sorry', 236),
#   ('uh', 233),
#   ('phoebe', 213),
#   ('going', 213),
#   ('tell', 207),
#   ('little', 192),
#   ('love', 179),
#   ('youre', 178),
#   ('thats', 174),
#   ('good', 173),
#   ('yknow', 160),
#   ('said', 155),
#   ('wait', 154),
#   ('honey', 152),
#   ('great', 152),
#   ('chandler', 144),
#   ('let', 143),
#   ('umm', 139),
#   ('time', 138),
#   ('thank', 137),
#   ('say', 137),
#   ('rachel', 135),
#   ('hey', 135),
#   ('thing', 134),
#   ('make', 134),
#   ('ok', 129),
#   ('phone', 127),
#   ('ll', 125)],
#  'Ross': [('know', 873),
#   ('uh', 598),
#   ('okay', 469),
#   ('like', 459),
#   ('im', 426),
#   ('right', 414),
#   ('gonna', 405),
#   ('mean', 381),
#   ('rachel', 369),
#   ('dont', 349),
#   ('think', 346),
#   ('don', 319),
#   ('hey', 306),
#   ('oh', 300),
#   ('really', 290),
#   ('yeah', 272),
#   ('want', 270),
#   ('look', 268),
#   ('got', 250),
#   ('joey', 249),
#   ('guys', 243),
#   ('come', 240),
#   ('going', 235),
#   ('chandler', 219),
#   ('little', 188),
#   ('ii', 183),
#   ('say', 180),
#   ('good', 179),
#   ('sorry', 177),
#   ('tell', 174),
#   ('thats', 170),
#   ('ll', 168),
#   ('youre', 165),
#   ('monica', 161),
#   ('great', 161),
#   ('time', 158),
#   ('ok', 147),
#   ('ross', 144),
#   ('thing', 142),
#   ('love', 138),
#   ('guy', 134),
#   ('god', 130),
#   ('umm', 126),
#   ('way', 125),
#   ('wanna', 125),
#   ('ve', 123),
#   ('phoebe', 122),
#   ('yknow', 119),
#   ('looks', 117),
#   ('believe', 114)]}

# %%
# Print the top 15 words said for each resort
for character, top_words in top_dict.items():
    print(character)
    print(', '.join([word for word, count in top_words[0:30]]))
    print('---')
# Out:
# Chandler
# know, like, gonna, right, im, think, joey, monica, okay, don, look, dont, ross, got, uh, mean, really, want, say, going, thats, oh, good, yeah, little, tell, come, time, guys, youre
# ---
# Joey
# know, right, like, hey, ross, gonna, uh, got, chandler, look, im, don, okay, yeah, think, dont, really, want, oh, good, guys, come, little, joey, mean, ll, rachel, say, monica, youre
# ---
# Monica
# know, gonna, chandler, right, like, think, really, mean, im, okay, dont, oh, don, rachel, god, want, got, phoebe, going, ross, look, joey, youre, come, little, tell, love, good, umm, guys
# ---
# Phoebe
# know, oh, like, okay, im, right, gonna, really, dont, don, yeah, monica, think, look, rachel, god, ross, want, good, guys, joey, chandler, got, mean, sorry, yknow, youre, ok, going, tell
# ---
# Rachel
# know, oh, gonna, ross, right, like, mean, im, don, god, okay, really, think, joey, dont, look, got, want, guys, come, monica, yeah, sorry, uh, phoebe, going, tell, little, love, youre
# ---
# Ross
# know, uh, okay, like, im, right, gonna, mean, rachel, dont, think, don, hey, oh, really, yeah, want, look, got, joey, guys, come, going, chandler, little, ii, say, good, sorry, tell
# ---

# %% [markdown]
# NOTE: At this point, we could go on and create word clouds. However, by looking at these top words, you can see that some of them have very little meaning and could be added to a stop words list, so let's do just that.

# %%
# Look at the most common top words --> add them to the stop word list
from collections import Counter

# Let's first pull out the top 30 words for each comedian
words = []
for character in data.columns:
    top = [word for (word, count) in top_dict[character]]
    for t in top:
        words.append(t)
        
words
# Out:
# ['know',
#  'like',
#  'gonna',
#  'right',
#  'im',
#  'think',
#  'joey',
#  'monica',
#  'okay',
#  'don',
#  'look',
#  'dont',
#  'ross',
#  'got',
#  'uh',
#  'mean',
#  'really',
#  'want',
#  'say',
#  'going',
#  'thats',
#  'oh',
#  'good',
#  'yeah',
#  'little',
#  'tell',
#  'come',
#  'time',
#  'guys',
#  'youre',
#  'thing',
#  'great',
#  'love',
#  'said',
#  'yknow',
#  'let',
#  'make',
#  'chandler',
#  'way',
#  'guy',
#  'big',
#  'hey',
#  'rachel',
#  've',
#  'sorry',
#  'll',
#  'wanna',
#  'yes',
#  'phoebe',
#  'didnt',
#  'know',
#  'right',
#  'like',
#  'hey',
#  'ross',
#  'gonna',
#  'uh',
#  'got',
#  'chandler',
#  'look',
#  'im',
#  'don',
#  'okay',
#  'yeah',
#  'think',
#  'dont',
#  'really',
#  'want',
#  'oh',
#  'good',
#  'guys',
#  'come',
#  'little',
#  'joey',
#  'mean',
#  'll',
#  'rachel',
#  'say',
#  'monica',
#  'youre',
#  'tell',
#  'man',
#  'guy',
#  'going',
#  'great',
#  'said',
#  'looks',
#  'thing',
#  'thats',
#  'starts',
#  'let',
#  'phoebe',
#  'make',
#  'maybe',
#  'sorry',
#  'big',
#  'gotta',
#  'listen',
#  'time',
#  'ya',
#  'know',
#  'gonna',
#  'chandler',
#  'right',
#  'like',
#  'think',
#  'really',
#  'mean',
#  'im',
#  'okay',
#  'dont',
#  'oh',
#  'don',
#  'rachel',
#  'god',
#  'want',
#  'got',
#  'phoebe',
#  'going',
#  'ross',
#  'look',
#  'joey',
#  'youre',
#  'come',
#  'little',
#  'tell',
#  'love',
#  'good',
#  'umm',
#  'guys',
#  'sorry',
#  'll',
#  'make',
#  'time',
#  'wanna',
#  'say',
#  'let',
#  'wait',
#  'monica',
#  'great',
#  'guy',
#  'maybe',
#  'thats',
#  'hey',
#  'yeah',
#  'uh',
#  'believe',
#  'thought',
#  'way',
#  'need',
#  'know',
#  'oh',
#  'like',
#  'okay',
#  'im',
#  'right',
#  'gonna',
#  'really',
#  'dont',
#  'don',
#  'yeah',
#  'monica',
#  'think',
#  'look',
#  'rachel',
#  'god',
#  'ross',
#  'want',
#  'good',
#  'guys',
#  'joey',
#  'chandler',
#  'got',
#  'mean',
#  'sorry',
#  'yknow',
#  'youre',
#  'ok',
#  'going',
#  'tell',
#  'thats',
#  'hey',
#  'guy',
#  'little',
#  'cause',
#  'umm',
#  'um',
#  'come',
#  'time',
#  'phoebe',
#  'say',
#  'great',
#  'love',
#  'make',
#  'hes',
#  'wait',
#  'let',
#  'maybe',
#  'said',
#  'looks',
#  'know',
#  'oh',
#  'gonna',
#  'ross',
#  'right',
#  'like',
#  'mean',
#  'im',
#  'don',
#  'god',
#  'okay',
#  'really',
#  'think',
#  'joey',
#  'dont',
#  'look',
#  'got',
#  'want',
#  'guys',
#  'come',
#  'monica',
#  'yeah',
#  'sorry',
#  'uh',
#  'phoebe',
#  'going',
#  'tell',
#  'little',
#  'love',
#  'youre',
#  'thats',
#  'good',
#  'yknow',
#  'said',
#  'wait',
#  'honey',
#  'great',
#  'chandler',
#  'let',
#  'umm',
#  'time',
#  'thank',
#  'say',
#  'rachel',
#  'hey',
#  'thing',
#  'make',
#  'ok',
#  'phone',
#  'll',
#  'know',
#  'uh',
#  'okay',
#  'like',
#  'im',
#  'right',
#  'gonna',
#  'mean',
#  'rachel',
#  'dont',
#  'think',
#  'don',
#  'hey',
#  'oh',
#  'really',
#  'yeah',
#  'want',
#  'look',
#  'got',
#  'joey',
#  'guys',
#  'come',
#  'going',
#  'chandler',
#  'little',
#  'ii',
#  'say',
#  'good',
#  'sorry',
#  'tell',
#  'thats',
#  'll',
#  'youre',
#  'monica',
#  'great',
#  'time',
#  'ok',
#  'ross',
#  'thing',
#  'love',
#  'guy',
#  'god',
#  'umm',
#  'way',
#  'wanna',
#  've',
#  'phoebe',
#  'yknow',
#  'looks',
#  'believe']

# %%
# Let's aggregate this list and identify the most common words along with how many routines they occur in
Counter(words).most_common()
# Out:
# [('know', 6),
#  ('like', 6),
#  ('gonna', 6),
#  ('right', 6),
#  ('im', 6),
#  ('think', 6),
#  ('joey', 6),
#  ('monica', 6),
#  ('okay', 6),
#  ('don', 6),
#  ('look', 6),
#  ('dont', 6),
#  ('ross', 6),
#  ('got', 6),
#  ('mean', 6),
#  ('really', 6),
#  ('want', 6),
#  ('say', 6),
#  ('going', 6),
#  ('thats', 6),
#  ('oh', 6),
#  ('good', 6),
#  ('yeah', 6),
#  ('little', 6),
#  ('tell', 6),
#  ('come', 6),
#  ('time', 6),
#  ('guys', 6),
#  ('youre', 6),
#  ('great', 6),
#  ('chandler', 6),
#  ('hey', 6),
#  ('rachel', 6),
#  ('sorry', 6),
#  ('phoebe', 6),
#  ('uh', 5),
#  ('love', 5),
#  ('let', 5),
#  ('make', 5),
#  ('guy', 5),
#  ('ll', 5),
#  ('thing', 4),
#  ('said', 4),
#  ('yknow', 4),
#  ('god', 4),
#  ('umm', 4),
#  ('way', 3),
#  ('wanna', 3),
#  ('looks', 3),
#  ('maybe', 3),
#  ('wait', 3),
#  ('ok', 3),
#  ('big', 2),
#  ('ve', 2),
#  ('believe', 2),
#  ('yes', 1),
#  ('didnt', 1),
#  ('man', 1),
#  ('starts', 1),
#  ('gotta', 1),
#  ('listen', 1),
#  ('ya', 1),
#  ('thought', 1),
#  ('need', 1),
#  ('cause', 1),
#  ('um', 1),
#  ('hes', 1),
#  ('honey', 1),
#  ('thank', 1),
#  ('phone', 1),
#  ('ii', 1)]

# %%
# If more than half of the characters have it as a top word, exclude it from the list
add_stop_words = [word for word, count in Counter(words).most_common() if count > 0]
add_stop_words_additional = ['chandler', 'joey', 'monica', 'phoebe', 'rachel', 'ross','guy','hi','start','ye','ha','pause','ah','huh','work','thi','does','didn','thought','didnt','actually','stop','wa'.'hand']
add_stop_words.extend(add_stop_words)
add_stop_words.extend(add_stop_words_additional)

# %%
# Let's update our document-term matrix with the new list of stop words
from sklearn.feature_extraction import text 
from sklearn.feature_extraction.text import CountVectorizer

# Read in cleaned data
data_clean = pd.read_pickle('../pickle/data_clean.pkl')

data_clean
# Out:
#                                                     Dialogue
# Character
# Chandler   right joey nice hump hump hairpiecesounds like...
# Joey       cmon youre going guy theres gotta something wr...
# Monica     theres nothing tell hes guy work withokay ever...
# Phoebe     wait eat chalkjust cause dont want go went car...
# Rachel     oh god monica hi thank god went building weren...
# Ross       mortified hii feel like someone reached throat...

# %%
print (add_stop_words)
# Add new stop words
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

# Recreate document-term matrix
cv = CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(data_clean.Dialogue)
data_stop = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_stop.index = data_clean.index
# Out:
# ['know', 'like', 'gonna', 'right', 'im', 'think', 'joey', 'monica', 'okay', 'don', 'look', 'dont', 'ross', 'got', 'mean', 'really', 'want', 'say', 'going', 'thats', 'oh', 'good', 'yeah', 'little', 'tell', 'come', 'time', 'guys', 'youre', 'great', 'chandler', 'hey', 'rachel', 'sorry', 'phoebe', 'uh', 'love', 'let', 'make', 'guy', 'll', 'thing', 'said', 'yknow', 'god', 'umm', 'way', 'wanna', 'looks', 'maybe', 'wait', 'ok', 'big', 've', 'believe', 'yes', 'didnt', 'man', 'starts', 'gotta', 'listen', 'ya', 'thought', 'need', 'cause', 'um', 'hes', 'honey', 'thank', 'phone', 'ii', 'know', 'like', 'gonna', 'right', 'im', 'think', 'joey', 'monica', 'okay', 'don', 'look', 'dont', 'ross', 'got', 'mean', 'really', 'want', 'say', 'going', 'thats', 'oh', 'good', 'yeah', 'little', 'tell', 'come', 'time', 'guys', 'youre', 'great', 'chandler', 'hey', 'rachel', 'sorry', 'phoebe', 'uh', 'love', 'let', 'make', 'guy', 'll', 'thing', 'said', 'yknow', 'god', 'umm', 'way', 'wanna', 'looks', 'maybe', 'wait', 'ok', 'big', 've', 'believe', 'yes', 'didnt', 'man', 'starts', 'gotta', 'listen', 'ya', 'thought', 'need', 'cause', 'um', 'hes', 'honey', 'thank', 'phone', 'ii', 'chandler', 'joey', 'monica', 'phoebe', 'rachel', 'ross', 'guy', 'hi', 'start', 'ye', 'ha', 'pause', 'ah', 'huh', 'work', 'thi', 'does', 'didn', 'thought', 'didnt', 'actually', 'stop', 'wa']

# %%
# Let's make some word clouds!
# Terminal / Anaconda Prompt: conda install -c conda-forge wordcloud
from wordcloud import WordCloud

wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)

# %%
# Reset the output dimensions
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 6]
character_names = ['Chandler', 'Joey', 'Monica', 'Phoebe', 'Rachel', 'Ross']

# Create subplots for each character
for index, character in enumerate(data.columns):
    wc.generate(data_clean.Dialogue[character])
    
    plt.subplot(3, 4, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(character_names[index])
    
plt.show()
